# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel("FIFA1.xlsx")
data.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3         L. SuÌÁrez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club     Value  Wage  Special Acceleration  ...     RB  \
# 0       Real Madrid CF   95500.0   565     2228           89  ...   61.0
# 1         FC Barcelona  105000.0   565     2154           92  ...   57.0
# 2  Paris Saint-Germain  123000.0   280     2100           94  ...   59.0
# 3         FC Barcelona   97000.0   510     2291           88  ...   64.0
# 4     FC Bayern Munich   61000.0   230     1493           58  ...    NaN
#
#     RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 69 columns):
# Name                  17981 non-null object
# Age                   17981 non-null int64
# Nationality           17981 non-null object
# Overall               17981 non-null int64
# Potential             17981 non-null int64
# Club                  17733 non-null object
# Value                 17725 non-null float64
# Wage                  17981 non-null int64
# Special               17981 non-null int64
# Acceleration          17981 non-null object
# Aggression            17981 non-null object
# Agility               17981 non-null object
# Balance               17981 non-null object
# Ball_control          17981 non-null object
# Composure             17981 non-null object
# Crossing              17981 non-null object
# Curve                 17981 non-null object
# Dribbling             17981 non-null object
# Finishing             17981 non-null object
# ...

# %%
data=data.dropna()
data.reset_index(drop=True, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15741 entries, 0 to 15740
# Data columns (total 69 columns):
# Name                  15741 non-null object
# Age                   15741 non-null int64
# Nationality           15741 non-null object
# Overall               15741 non-null int64
# Potential             15741 non-null int64
# Club                  15741 non-null object
# Value                 15741 non-null float64
# Wage                  15741 non-null int64
# Special               15741 non-null int64
# Acceleration          15741 non-null object
# Aggression            15741 non-null object
# Agility               15741 non-null object
# Balance               15741 non-null object
# Ball_control          15741 non-null object
# Composure             15741 non-null object
# Crossing              15741 non-null object
# Curve                 15741 non-null object
# Dribbling             15741 non-null object
# Finishing             15741 non-null object
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Special', 'Acceleration', 'Aggression', 'Agility', 'Balance',
#        'Ball_control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
#        'Finishing', 'Free_kick_accuracy', 'GK_diving', 'GK_handling',
#        'GK_kicking', 'GK_positioning', 'GK_reflexes', 'Heading_accuracy',
#        'Interceptions', 'Jumping', 'Long_passing', 'Long_shots', 'Marking',
#        'Penalties', 'Positioning', 'Reactions', 'Short_passing', 'Shot_power',
#        'Sliding_tackle', 'Sprint_speed', 'Stamina', 'Standing_tackle',
#        'Strength', 'Vision', 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'LAM',
#        'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'RAM', 'RB',
#        'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
position=data.loc[:,['CAM', 'CB', 'CDM', 'CF', 'CM', 'LAM',
       'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'RAM', 'RB',
       'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST']]

# %%
position.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15741 entries, 0 to 15740
# Data columns (total 26 columns):
# CAM    15741 non-null float64
# CB     15741 non-null float64
# CDM    15741 non-null float64
# CF     15741 non-null float64
# CM     15741 non-null float64
# LAM    15741 non-null float64
# LB     15741 non-null float64
# LCB    15741 non-null float64
# LCM    15741 non-null float64
# LDM    15741 non-null float64
# LF     15741 non-null float64
# LM     15741 non-null float64
# LS     15741 non-null float64
# LW     15741 non-null float64
# LWB    15741 non-null float64
# RAM    15741 non-null float64
# RB     15741 non-null float64
# RCB    15741 non-null float64
# RCM    15741 non-null float64
# RDM    15741 non-null float64
# RF     15741 non-null float64
# RM     15741 non-null float64
# RS     15741 non-null float64
# RW     15741 non-null float64
# RWB    15741 non-null float64
# ST     15741 non-null float64
# dtypes: float64(26)
# memory usage: 3.1 MB

# %%
position["Real"]=position.idxmax(axis=1)

# %%
position["Real"]
# Out:
# 0         LS
# 1        CAM
# 2         LW
# 3         CF
# 4         LS
# 5        CAM
# 6         CM
# 7         LS
# 8         CB
# 9        CAM
# 10        LW
# 11       CAM
# 12        CF
# 13        CF
# 14        CB
# 15        LW
# 16        LW
# 17       CAM
# 18        LS
# 19        CB
# 20        CB
# 21        CB
# 22        CB
# 23       CAM
# 24        CB
# 25        LS
# 26        LW
# 27       CDM
# 28        CM
# 29       CAM
#         ...
# 15711     CB
# 15712     LS
# 15713     LM
# 15714    CAM
# 15715     LM
# 15716     LM
# 15717     CB
# 15718     CB
# 15719     LB
# 15720     CB
# 15721     LM
# 15722    CAM
# 15723     CB
# 15724     CB
# 15725     CB
# 15726     CB
# 15727     LM
# 15728     CB
# 15729     CB
# 15730     CB
# 15731     LW
# 15732     CB
# 15733     LS
# 15734     LB
# 15735     LM
# 15736     LB
# 15737     CM
# 15738     CF
# 15739    CDM
# 15740     CB
# Name: Real, Length: 15741, dtype: object

# %%
data_total=data.join(position["Real"])

# %%
data_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15741 entries, 0 to 15740
# Data columns (total 70 columns):
# Name                  15741 non-null object
# Age                   15741 non-null int64
# Nationality           15741 non-null object
# Overall               15741 non-null int64
# Potential             15741 non-null int64
# Club                  15741 non-null object
# Value                 15741 non-null float64
# Wage                  15741 non-null int64
# Special               15741 non-null int64
# Acceleration          15741 non-null object
# Aggression            15741 non-null object
# Agility               15741 non-null object
# Balance               15741 non-null object
# Ball_control          15741 non-null object
# Composure             15741 non-null object
# Crossing              15741 non-null object
# Curve                 15741 non-null object
# Dribbling             15741 non-null object
# Finishing             15741 non-null object
# ...

# %%
data_final=data_total.drop(['CAM', 'CB', 'CDM', 'CF', 'CM', 'LAM',
       'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'RAM', 'RB',
       'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST','Special'],axis=1)

# %%
data_final.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3         L. SuÌÁrez   30     Uruguay       92         92
# 4     R. Lewandowski   28      Poland       91         91
#
#                   Club     Value  Wage Acceleration Aggression ...   \
# 0       Real Madrid CF   95500.0   565           89         63 ...
# 1         FC Barcelona  105000.0   565           92         48 ...
# 2  Paris Saint-Germain  123000.0   280           94         56 ...
# 3         FC Barcelona   97000.0   510           88         78 ...
# 4     FC Bayern Munich   92000.0   355           79         80 ...
#
#   Short_passing Shot_power Sliding_tackle Sprint_speed Stamina  \
# 0            83         94             23           91      92
# 1            88         85             26           87      73
# ...

# %%
draft=data_final.loc[:,['Acceleration', 'Aggression', 'Agility', 'Balance',
       'Ball_control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
       'Finishing', 'Free_kick_accuracy', 'GK_diving', 'GK_handling',
       'GK_kicking', 'GK_positioning', 'GK_reflexes', 'Heading_accuracy',
       'Interceptions', 'Jumping', 'Long_passing', 'Long_shots', 'Marking',
       'Penalties', 'Positioning', 'Reactions', 'Short_passing', 'Shot_power',
       'Sliding_tackle', 'Sprint_speed', 'Stamina', 'Standing_tackle',
       'Strength', 'Vision', 'Volleys']]

# %%
#for i in range (len(draft.Balance)):
 #   draft.Balance[i] = eval(str(draft.Balance[i]))

# %%
#draft.Balance.unique()

# %%
names=draft.columns
for k in names:
    for i in range (0,15741):
        draft[k][i]= eval(str(draft[k][i]))

# %%
names=draft.columns
for k in names:
    print(draft[k].unique())
# Out:
# [89 92 94 88 79 93 60 78 75 76 90 68 87 77 95 62 72 70 63 82 69 67 55 74
#  86 84 48 80 49 71 65 85 53 73 61 64 42 81 91 51 52 54 66 39 83 96 31 57
#  50 44 40 26 35 58 36 38 43 46 47 59 32 45 37 30 56 33 34 41 28 22 29 24
#  27 20 25]
# [63 48 56 78 80 54 60 50 84 68 62 65 92 69 57 43 82 86 66 77 47 90 89 75
#  44 93 67 51 72 58 74 85 55 49 81 88 91 59 83 45 52 94 61 87 34 70 73 71
#  79 40 30 64 76 23 46 33 42 38 32 53 35 41 36 27 39 29 96 31 24 28 26 37
#  22 25 106 21 19 15 95 16 13 18]
# [89 90 96 86 78 93 71 75 79 80 77 59 91 60 58 63 64 83 74 81 87 76 72 92
#  73 82 62 54 94 61 65 88 66 34 51 49 50 68 84 53 57 85 33 45 69 56 38 70
#  43 67 48 29 52 27 42 35 47 46 55 30 32 44 37 41 39 28 40 36 31 26 95 25
#  24 23]
# [63 95 82 60 80 91 69 75 87 94 65 64 85 86 70 52 53 58 68 41 90 61 77 59
#  66 89 42 84 62 47 79 72 55 92 81 50 56 57 49 71 93 73 76 40 78 67 36 51
#  32 83 88 35 31 38 74 39 48 54 46 43 34 28 45 96 37 29 33 44 30 27 25 24
#  26 22 21]
# ...

# %%
data_final.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club', 'Value',
#        'Wage', 'Acceleration', 'Aggression', 'Agility', 'Balance',
#        'Ball_control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
#        'Finishing', 'Free_kick_accuracy', 'GK_diving', 'GK_handling',
#        'GK_kicking', 'GK_positioning', 'GK_reflexes', 'Heading_accuracy',
#        'Interceptions', 'Jumping', 'Long_passing', 'Long_shots', 'Marking',
#        'Penalties', 'Positioning', 'Reactions', 'Short_passing', 'Shot_power',
#        'Sliding_tackle', 'Sprint_speed', 'Stamina', 'Standing_tackle',
#        'Strength', 'Vision', 'Volleys', 'Real'],
#       dtype='object')

# %%
draft.columns
# Out:
# Index(['Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball_control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free_kick_accuracy', 'GK_diving', 'GK_handling', 'GK_kicking',
#        'GK_positioning', 'GK_reflexes', 'Heading_accuracy', 'Interceptions',
#        'Jumping', 'Long_passing', 'Long_shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short_passing', 'Shot_power',
#        'Sliding_tackle', 'Sprint_speed', 'Stamina', 'Standing_tackle',
#        'Strength', 'Vision', 'Volleys'],
#       dtype='object')

# %%
new_data=draft.join(data_final[['Name','Age','Nationality','Overall','Potential','Club','Value','Wage','Real']])

# %%
new_data.head()
# Out:
#   Acceleration Aggression Agility Balance Ball_control Composure Crossing  \
# 0           89         63      89      63           93        95       85
# 1           92         48      90      95           95        96       77
# 2           94         56      96      82           95        92       75
# 3           88         78      86      60           91        83       77
# 4           79         80      78      80           89        87       62
#
#   Curve Dribbling Finishing ...  Volleys               Name Age Nationality  \
# 0    81        91        94 ...       88  Cristiano Ronaldo  32    Portugal
# 1    89        97        95 ...       85           L. Messi  30   Argentina
# 2    81        96        89 ...       83             Neymar  25      Brazil
# 3    86        86        94 ...       88         L. SuÌÁrez  30     Uruguay
# 4    77        85        91 ...       87     R. Lewandowski  28      Poland
#
#   Overall Potential                 Club     Value Wage Real
# ...

# %%
new_data.to_excel("FIFA7.xlsx")

# %%
new_data_full=new_data.join(data[['CAM', 'CB', 'CDM', 'CF', 'CM', 'LAM',
       'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'RAM', 'RB',
       'RCB', 'RCM', 'RDM', 'RF', 'RM', 'RS', 'RW', 'RWB', 'ST']])

# %%
new_data_full.to_excel("FIFA_comp.xlsx")
